# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time
import json
import googlemaps

# %% [markdown]
# <h1>Web Scraping Project: Stores in the Belgium</h1>
# In this project, the client needs data for the stores in Belgium from certain websites. Some websites may have challenges such as, anti bot, requires VPN, and many more. The data field needed to be extracted from each websites are:
#
# - Location Name
# - Country
# - Coordinates (Longitude & Latitude)
# - Parking Type (if available)
# - Contact First Name
# - Contact Last Name
# - Contact Email
# - Contact Phone Number

# %% [markdown]
# <h2>1. LE ROI DU MATELAS</h1>
# The website is actually quite straightforward. All the contents of the websites are actually stored in the API.

# %%
with open('le_rois.json', 'r', encoding='utf-8') as file:
    content = file.read().strip()  # Read and strip any whitespace
    if content:  # Check if the file is not empty
        data = json.loads(content)  # Load JSON from the content
        print(data)
    else:
        print("The file is empty.")
# Reading data in merchantStores
stores = data['merchantStores']


# Extracting required fields from merchantStores
results = []
for store in stores:
    schedules = store.get('schedules', [])
    opening_hours = []
    for s in schedules:
        if s["am_opening"] and s["am_closing"]:
            opening = f"{s['am_opening']} - {s['am_closing']}"
        else:
            opening = "-"
        if s["pm_opening"] and s["pm_closing"]:
            closing = f"{s['pm_opening']} - {s['pm_closing']}"
        else:
            closing = "-"
        opening_hours.append(f"{s['day']}: {opening}, {closing}")

    results.append({
        "Location Name": store.get("name", "-"),
        "Address": store.get("street", "-"),
        "Postal Code": store.get("postcode", ""),
        "City": store.get("city", "-").title(),
        "Country": store.get("country_id", "FR"),
        "Parking Type": store.get("parking_type", "Not Available"),
        "Contact First Name": store.get("contact_name", "Not Available"),
        "Contact Last Name": store.get("contact_lastname", "Not Available"),
        "Contact Phone": store.get("phone", "-").strip().replace(" ", ""),
        "Contact Email": store.get("email", "-"),
        "Latitude": store.get("latitude", "-"),
        "Longitude": store.get("longitude", "-"),
        "Opening Hours": "\n".join(opening_hours)
    })

df = pd.DataFrame(results)
# Mapping country codes ke country names
country_map = {
    "FR": "France",
    "BE": "Belgium",
    "LU": "Luxembourg"
}

# Ubah kode negara menjadi nama lengkap
df["Country Full"] = df["Country"].map(country_map)

# Buat kolom Full Address
df["Address"] = df["Address"].astype(str).str.strip()
df["Full Address"] = df["Address"] + ", " +df['Postal Code']+ ", " +df['City']+", "+ df["Country Full"]
df = df[['Location Name', 'Full Address', 'Latitude', 'Longitude','Parking Type','Contact First Name','Contact Last Name','Contact Phone', 'Contact Email']]
df
# Out:
# {'success': True, 'merchantStores': [{'entity_id': '13', 'name': 'ABBEVILLE', 'description': None, 'code': '1512', 'is_virtual': '0', 'parent_id': None, 'street': '200 rue des chênes ', 'postcode': '80132', 'city': 'VAUCHELLES LES QUESNOY', 'country_id': 'FR', 'phone': '(+33)3 22 24 12 55', 'email': 'abbeville@leroidumatelas.fr', 'latitude': '50.0964', 'longitude': '1.87074', 'schedules': [{'day': 'Monday', 'am_opening': '10:00', 'am_closing': '12:30', 'is_am_closed': '0', 'pm_opening': '14:00', 'pm_closing': '19:00', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '0'}, {'day': 'Tuesday', 'am_opening': '10:00', 'am_closing': '12:30', 'is_am_closed': '0', 'pm_opening': '14:00', 'pm_closing': '19:00', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '1'}, {'day': 'Wednesday', 'am_opening': '10:00', 'am_closing': '12:30', 'is_am_closed': '0', 'pm_opening': '14:00', 'pm_closing': '19:00', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '2'}, {'day': 'Thursday', 'am_opening': '10:00', 'am_closing': '12:30', 'is_am_closed': '0', 'pm_opening': '14:00', 'pm_closing': '19:00', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '3'}, {'day': 'Friday', 'am_opening': '10:00', 'am_closing': '12:30', 'is_am_closed': '0', 'pm_opening': '14:00', 'pm_closing': '19:00', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '4'}, {'day': 'Saturday', 'am_opening': '10:00', 'am_closing': '13:30', 'is_am_closed': '0', 'pm_opening': '13:30', 'pm_closing': '19:00', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '5'}, {'day': 'Sunday', 'am_opening': '', 'am_closing': '', 'is_am_closed': '0', 'pm_opening': '', 'pm_closing': '', 'is_pm_closed': '0', 'initialize': 'true', 'record_id': '6'}], 'is_closed': '0', 'is_main': '0', 'magento_store_id': '1', 'updated_at': '2024-10-08 06:29:58', 'created_at': '2023-08-02 15:26:42', 'lrdm_entity_id': '15', 'news_content': [{'store_id': '1', 'initialize': 'true', 'record_id': '0', 'title': '<p>En ce moment dans votre magasin\xa0</p>', 'description': '', 'image': [{'name': 'MAGASIN_-_536x333_1905.jpg', 'full_path': 'MAGASIN - 536x333.jpg', 'type': 'image/jpeg', 'tmp_name': '/tmp/php7GsN1o', 'error': '0', 'size': '70384', 'file': 'MAGASIN_-_536x333_1905.jpg', 'url': 'https://www.leroidumatelas.fr/media/lrdm/tmp/MAGASIN_-_536x333_1905.jpg', 'cookie': {'name': 'admin', 'value': 'sgellk5f2k33srssru6hofqu1f', 'lifetime': '31536000', 'path': '/mgn_k2hE2CD', 'domain': 'admin.leroidumatelas.fr'}, 'previewType': 'image', 'id': 'TUFHQVNJTl8tXzUzNngzMzNfMTkwNS5qcGc,'}]}, {'store_id': '3', 'initialize': 'true', 'record_id': '1', 'title': '<p>En ce moment dans votre magasin\xa0</p>', 'description': '', 'image': [{'name': 'MAGASIN_-_536x333_1906.jpg', 'full_path': 'MAGASIN - 536x333.jpg', 'type': 'image/jpeg', 'tmp_name': '/tmp/php07zm7l', 'error': '0', 'size': '70384', 'file': 'MAGASIN_-_536x333_1906.jpg', 'url': 'https://www.leroidumatelas.fr/media/lrdm/tmp/MAGASIN_-_536x333_1906.jpg', 'cookie': {'name': 'admin', 'value': 'sgellk5f2k33srssru6hofqu1f', 'lifetime': '31536000', 'path': '/mgn_k2hE2CD', 'domain': 'admin.leroidumatelas.fr'}, 'previewType': 'image', 'id': 'TUFHQVNJTl8tXzUzNngzMzNfMTkwNi5qcGc,'}]}, {'store_id': '5', 'initialize': 'true', 'record_id': '2', 'title': '<p>Nu in uw winkeml</p>', 'description': '', 'image': [{'name': 'MAGASIN_-_536x333_-_NL_41.jpg', 'full_path': 'MAGASIN - 536x333 - NL.jpg', 'type': 'image/jpeg', 'tmp_name': '/tmp/phpaAONdj', 'error': '0', 'size': '127198', 'file': 'MAGASIN_-_536x333_-_NL_41.jpg', 'url': 'https://www.leroidumatelas.fr/media/lrdm/tmp/MAGASIN_-_536x333_-_NL_41.jpg', 'cookie': {'name': 'admin', 'value': 'sgellk5f2k33srssru6hofqu1f', 'lifetime': '31536000', 'path': '/mgn_k2hE2CD', 'domain': 'admin.leroidumatelas.fr'}, 'previewType': 'image', 'id': 'TUFHQVNJTl8tXzUzNngzMzNfLV9OTF80MS5qcGc,'}]}, {'store_id': '7', 'initialize': 'true', 'record_id': '3', 'title': '<p>En ce moment dans votre magasin\xa0</p>', 'description': '', 'image': [{'name' ...
#          Location Name                                       Full Address  \
# 0            ABBEVILLE  200 rue des chênes, 80132, Vauchelles Les Ques...
# 1               AMIENS            660 Route d'Amiens, 80480, Dury, France
# 2               ALLEUR         Avenue du Progrés 5, 4432, Alleur, Belgium
# 3             BASTOGNE       Chaussée d'Arlon 50, 6600, Bastogne, Belgium
# 4   BRUAY LA BUISSIÈRE  Zone commerciale CGR, 62700, Bruay La Buissièr...
# ..                 ...                                                ...
# 61            POITIERS     8 route de la Saulaie, 86000, Poitiers, France
# 62          SANDWEILER  Route de Luxembourg, 11, L-5230, Sandweiler, L...
# 63           DROGENBOS  Verlengde Stallestraat 217, 1620, Drogenbos, B...
# 64             ANCENIS  460 boulevard de la Prairie- Espace 23 Sud, 44...
# 65         SAINT-MALO   46 rue du Général Patton, 35400, Saint-Malo, F...
#
#    Latitude Longitude   Parking Type Contact First Name Contact Last Name  \
# 0   50.0964   1.87074  Not Available      Not Available     Not Available
# 1   49.8737    2.2808  Not Available      Not Available     Not Available
# 2   50.6729   5.52708  Not Available      Not Available     Not Available
# 3   49.9947   5.71702  Not Available      Not Available     Not Available
# 4   50.4955   2.58211  Not Available      Not Available     Not Available
# ..      ...       ...            ...                ...               ...
# 61  46.5485  0.297472  Not Available      Not Available     Not Available
# 62  49.6151    6.2074  Not Available      Not Available     Not Available
# 63  50.7954   4.31704  Not Available      Not Available     Not Available
# 64  47.3743  -1.19366  Not Available      Not Available     Not Available
# 65  48.6213  -1.99456  Not Available      Not Available     Not Available
#
#       Contact Phone                       Contact Email
# 0    (+33)322241255         abbeville@leroidumatelas.fr
# 1    (+33)322330152            amiens@leroidumatelas.fr
# 2   (+32)3242631824                      alleur@lrdm.eu
# 3     (+32)61216723                    bastogne@lrdm.eu
# 4    (+33)321523865  bruaylabuissiere@leroidumatelas.fr
# ..              ...                                 ...
# 61   (+33)549412177          poitiers@leroidumatelas.fr
# 62  (+352)621786132                  sandweiler@lrdm.eu
# 63    (+32)23767023                   drogenbos@lrdm.eu
# 64   (+33)966803974                     ancenis@lrdm.eu
# 65   (+33)299823264                   saintmalo@lrdm.eu
#
# [66 rows x 9 columns]

# %% [markdown]
# <h2>2. Handy Home</h2>
# Just like the previous store,

# %%
with open('handy_home.json', 'r', encoding='utf-8') as file:
    content = file.read().strip()  # Read and strip any whitespace
    if content:  # Check if the file is not empty
        data = json.loads(content)  # Load JSON from the content
        print(data)
    else:
        print("The file is empty.")
handy = data['dealers']
handy_results = []
for store in handy:
    handy_results.append({
        'Location Name': store.get('title', '-'),
        'Address':store.get('street','-'),
        'City':store.get('city','-').title(),
        'Postal Code':store.get('pcode','Not Available'),
        'Coordinate':store.get('coord','-'),
        'Parking Type':store.get('parking_type', 'Not Avaliable'),medi-
        'Contact First Name': store.get('first name', "Not Available"),
        'Contact Last Name':store.get('last_name', "Not Available"),
        'Contact Email':store.get('email', "Not Available"),
        'Contact Phone':store.get('tel', 'Not Available')
    })
df = pd.DataFrame(handy_results)
df[['Longitude', 'Latitude']] = df['Coordinate'].str.split(';', expand=True)
df["Full Address"] = df["Address"] + ", " +df['Postal Code']+ ", " +df['City']+", "+ "Belgium"
df = df[['Location Name', 'Full Address', 'Latitude', 'Longitude','Parking Type','Contact First Name','Contact Last Name','Contact Phone', 'Contact Email']]
df
# Out:
# {'dealers': [{'id': 240, 'title': 'NOBEL sa', 'street': 'Rue des Champs, 10', 'pcode': '1040', 'city': 'BRUXELLES', 'tel': '02/648.05.94', 'email': 'info@nobel-sa.be', 'site': 'www.nobel-sa.be', 'website': 1, 'shop': 0, 'alg_site_id': 3, 'coord': '50.8304164;4.388814', 'url_identifier': 'nobel.handyhome.be', 'monday': '08:30-12:30|13:30-18:30', 'tuesday': '08:30-12:30|13:30-18:30', 'wednesday': '08:30-12:30|13:30-18:30', 'thursday': '08:30-12:30|13:30-18:30', 'friday': '08:30-12:30|13:30-18:30', 'saturday': '08:30-12:30|13:30-18:30', 'sunday': '08:30-12:30|13:30-18:30', 'distance': 2.9039302084117646, 'openingHours': {'full': '<strong>Maandag:<br></strong>08:30 - 12:30 | 13:30 - 18:30<hr><strong>Dinsdag:<br></strong>08:30 - 12:30 | 13:30 - 18:30<hr><strong>Woensdag:<br></strong>08:30 - 12:30 | 13:30 - 18:30<hr><strong>Donderdag:<br></strong>08:30 - 12:30 | 13:30 - 18:30<hr><strong>Vrijdag:<br></strong>08:30 - 12:30 | 13:30 - 18:30<hr><strong>Zaterdag:<br></strong>08:30 - 12:30 | 13:30 - 18:30<hr><strong>Zondag:<br></strong>08:30 - 12:30 | 13:30 - 18:30', 'alert': 'We zijn open tot <strong>18:30.</strong>'}}, {'id': 257, 'title': 'ORGA MERCHTEM', 'street': 'Stationstraat 114-118', 'pcode': '1785', 'city': 'MERCHTEM', 'tel': '052/25.04.25', 'email': 'merchtem@handyhome.be', 'site': '', 'website': 0, 'shop': 0, 'alg_site_id': 3, 'coord': '50.9545138;4.2255168', 'url_identifier': 'www.orgamerchtem.be', 'monday': '08:00-19:00', 'tuesday': '08:00-19:00', 'wednesday': '08:00-19:00', 'thursday': '08:00-19:00', 'friday': '08:00-19:00', 'saturday': '08:00-18:00', 'sunday': '', 'distance': 15.251953350773016, 'openingHours': {'full': '<strong>Maandag:<br></strong>08:00 - 19:00<hr><strong>Dinsdag:<br></strong>08:00 - 19:00<hr><strong>Woensdag:<br></strong>08:00 - 19:00<hr><strong>Donderdag:<br></strong>08:00 - 19:00<hr><strong>Vrijdag:<br></strong>08:00 - 19:00<hr><strong>Zaterdag:<br></strong>08:00 - 18:00', 'alert': 'We zijn open tot <strong>19:00.</strong>'}}, {'id': 241, 'title': 'HANDYHOME DENDERLEEUW', 'street': 'Koopwarenstraat 25', 'pcode': '9470', 'city': 'DENDERLEEUW', 'tel': '053/89.10.10', 'email': 'denderleeuw@handyhome.be', 'site': '', 'website': 1, 'shop': 0, 'alg_site_id': 3, 'coord': '50.8865227;4.0754627', 'url_identifier': 'www.handyhome-denderleeuw.be', 'monday': '08:00-19:00', 'tuesday': '08:00-19:00', 'wednesday': '08:00-19:00', 'thursday': '08:00-19:00', 'friday': '08:00-19:00', 'saturday': '08:00-18:00', 'sunday': '', 'distance': 21.33594893017849, 'openingHours': {'full': '<strong>Maandag:<br></strong>08:00 - 19:00<hr><strong>Dinsdag:<br></strong>08:00 - 19:00<hr><strong>Woensdag:<br></strong>08:00 - 19:00<hr><strong>Donderdag:<br></strong>08:00 - 19:00<hr><strong>Vrijdag:<br></strong>08:00 - 19:00<hr><strong>Zaterdag:<br></strong>08:00 - 18:00', 'alert': 'We zijn open tot <strong>19:00.</strong>'}}, {'id': 214, 'title': 'FERA DHZ', 'street': 'Industriepark De Vliet', 'pcode': '2880', 'city': 'BORNEM', 'tel': '03/740.55.55', 'email': 'info@fera.be', 'site': '', 'website': 1, 'shop': 0, 'alg_site_id': 3, 'coord': '51.0877839;4.2732444', 'url_identifier': 'www.fera-handyhome.be', 'monday': '08:00-19:00', 'tuesday': '', 'wednesday': '08:00-19:00', 'thursday': '08:00-19:00', 'friday': '08:00-19:00', 'saturday': '08:00-17:30', 'sunday': '08:00-17:30', 'distance': 26.84156462497485, 'openingHours': {'full': '<strong>Maandag:<br></strong>08:00 - 19:00<hr><strong>Woensdag:<br></strong>08:00 - 19:00<hr><strong>Donderdag:<br></strong>08:00 - 19:00<hr><strong>Vrijdag:<br></strong>08:00 - 19:00<hr><strong>Zaterdag:<br></strong>08:00 - 17:30<hr><strong>Zondag:<br></strong>08:00 - 17:30', 'alert': 'We zijn open tot <strong>19:00.</strong>'}}, {'id': 137, 'title': 'HANDYHOME WIELANT', 'street': 'Rempart St Joseph, 34', 'pcode': '7850', 'city': 'ENGHIEN', 'tel': '02 395 56 06', 'email': 'info@hobbylant.com', 'site': 'www.wielant.be', 'website': 1, 'shop': 0, 'alg_site_id': 3, 'coord': '50.6967713;4.0374062', 'url_identifier': 'ww ...
#                   Location Name  \
# 0                      NOBEL sa
# 1                 ORGA MERCHTEM
# 2         HANDYHOME DENDERLEEUW
# 3                      FERA DHZ
# 4             HANDYHOME WIELANT
# 5                     KERKSTOEL
# 6                  DEN ANKER nv
# 7          DOE HET ZELF CENTRUM
# 8      HANDYHOME DHZ SANIVER BV
# 9                        GONDRY
# 10           GEREEDSCHAPPEN LUC
# 11                      FALISSE
# 12             VANDENDRIES bvba
# 13       BRICO STOCK QUATTRO nv
# 14                 OTTEVAERE NV
# 15              CARLIER BOIS SA
# 16    AMERIKAANSE STOCK PAAL nv
# 17           LEGERSTOCK DE WULF
# 18           RAMBEAUX-DOR  S.A.
# 19                         KLUS
# 20                 CORSWAREM SA
# 21               EUROPOINT N.V.
# 22  HANDYHOME DEVOLDER-COUSSENS
# 23            LEGERSTOCK LUYCKX
# 24                      METALOR
# 25                      MOLS NV
# 26                       GLOBUS
# 27           TUINHOBBY ST MARIE
# 28               BRICO RULOT SA
# 29              DUVAN & Co SPRL
# 30                   SCHROEDERS
# 31                   DHZ LOUAGE
# 32         GILLON QUINCAILLERIE
# 33     BOUWSHOPPING VERHEYEN NV
# 34           BRICO SERVICE SPRL
# 35                    L'ANGELUS
# 36     QUINCAILLERIE CONRADT SA
# 37                    GARSOU SA
# 38                  TYCHON SPRL
# 39                    VAN MAELE
# 40                 TECNIBA S.A.
# 41                      ARMA SA
#
#                                          Full Address            Latitude  \
# 0        Rue des Champs, 10, 1040, Bruxelles, Belgium            4.388814
# 1      Stationstraat 114-118, 1785, Merchtem, Belgium           4.2255168
# 2      Koopwarenstraat 25, 9470, Denderleeuw, Belgium           4.0754627
# 3       Industriepark De Vliet, 2880, Bornem, Belgium           4.2732444
# 4       Rempart St Joseph, 34, 7850, Enghien, Belgium           4.0374062
# 5     Leopoldlei 54, 2220, Heist Op Den Berg, Belgium   4.728414597622421
# 6           Elisabethlaan 61, 3200, Aarschot, Belgium           4.8342596
# 7              HOOGSTRAAT 160, 9550, Herzele, Belgium   3.867974968888189
# 8            MOLENSTRAAT 195, 9150, Kruibeke, Belgium           4.3038358
# 9    RUE DE L'HOTELLERIE 105, 7860, Lessines, Belgium          3.84093840
# 10               Zillebeek 18, 9120, Beveren, Belgium           4.2297265
# 11   CHAUSSEE DE CHARLEROI 10, 6220, Fleurus, Belgium           4.5533991
# 12          Turnhoutsebaan 135, 3271, Zichem, Belgium            5.014304
# 13            STEENSTRAAT 4B, 3450, Geetbets, Belgium           5.1115043
# 14   MEERSBLOEM-LEUPEGEM 2, 9700, Oudenaarde, Belgium           3.5998024
# 15        AVENUE ALBERT 1ER 255, 5000, Namur, Belgium   4.891821082976176
# 16   PAALSESTEENWEG 284, 3583, Paal-Beringen, Belgium           5.1792049
# 17      Kortrijksesteenweg 185, 9800, Deinze, Belgium  3.5200774574984965
# 18  AVENUE REINE ELISABETH 13, 5300, Andenne, Belgium           5.0958261
# 19        HEPPENSESTEENWEG 41, 3581, Beverlo, Belgium           5.2247444
# 20             RUE DE HUY 155, 4300, Waremme, Belgium           5.2667307
# 21      GENTSEWEG 494, 8793, St-Eloois-Vijve, Belgium           3.3951271
# 22           TILETUMSTRAAT 62, 8755, Wingene, Belgium           3.3928497
# 23    Kerkhovensessteenweg 220, 3920, Lommel, Belgium           5.2805433
# 24  INGELMUNSTERSTEENWEG 23, 8780, Oostrozebeke, B...   3.321850491847764
# 25            De Raetstraat 38, 3920, Lommel, Belgium           5.2764633
# 26              RIJKSWEG 35, 8860, Lendelede, Belgium   3.230788343585026
# 27          SIJSELESTRAAT 48A, 8730, Oedelem, Belgium           3.3383537
# 28            Rue de Montys 16, 4557, Tinlot, Belgium           5.3838598
# 29    Rue Provinciale 523, 4458, Fexhe-Slins, Belgium           5.5674363
# 30           TRICHTERWEG 58, 3690, Zutendaal, Belgium           5.5995059
# 31     DADIZEELSESTRAAT 222, 8890, Moorslede, Belgium           3.0889954
# 32        RUE DE LA STATION 75, 4032, Chenee, Belgium           5.6144635
# 33    NIJVERHEIDSLAAN 24, 3630, Maasmechelen, Belgium           5.7045480
# 34            RUE DU NOYER 34, 6990, Melreux, Belgium           5.4375188
# 35             NIEUWSTRAAT 21, 8420, De Haan, Belgium           3.0358790
# 36         RUE DE LA PAIX 44, 4800, Verviers, Belgium           5.8460061
# 37                 LES DIGUES 5, 4910, Theux, Belgium   5.825803624910678
# 38       Rue de Liege 275, 4720, La Calamine, Belgium            6.006102
# 39         TOEVLUCHTWEG 12, 8620, Nieuwpoort, Belgium           2.7642735
# 40           RUE DE WILTZ 33, 6600, Bastogne, Belgium           5.7270100
# 41  RUE DES ARDENNES 89, 6780, Wolkrange (Messancy...           5.8154946
#
#              Longitude   Parking Type Contact First Name Contact Last Name  \
# 0           50.8304164  Not Avaliable      Not Available     Not Available
# 1           50.9545138  Not Avaliable      Not Available     Not Available
# 2           50.8865227  Not Avaliable      Not Available     Not Available
# 3           51.0877839  Not Avaliable      Not Available     Not Available
# 4           50.6967713  Not Avaliable      Not Available     Not Available
# 5   51.080491563037675  Not Avaliable      Not Available     Not Available
# 6           50.9874493  Not Avaliable      Not Available     Not Available
# 7    50.87865436076162  Not Avaliable      Not Available     Not Available
# 8           51.1763057  Not Avaliable      Not Available     Not Available
# 9           50.7093595  Not Avaliable      Not Available     Not Available
# 10          51.2219623  Not Avaliable      Not Available     Not Available
# 11            50.48559  Not Avaliable      Not Available     Not Available
# 12           51.030612  Not Avaliable      Not Available     Not Available
# 13          50.8916698  Not Avaliable      Not Available     Not Available
# 14          50.8342641  Not Avaliable      Not Available     Not Available
# 15  50.467954776368146  Not Avaliable      Not Available     Not Available
# 16          51.0408689  Not Avaliable      Not Available     Not Available
# 17   50.97255063213679  Not Avaliable      Not Available     Not Available
# 18          50.4911213  Not Avaliable      Not Available     Not Available
# 19          51.0913360  Not Avaliable      Not Available     Not Available
# 20          50.6535512  Not Avaliable      Not Available     Not Available
# 21          50.8965228  Not Avaliable      Not Available     Not Available
# 22          51.0331771  Not Avaliable      Not Available     Not Available
# 23          51.1708023  Not Avaliable      Not Available     Not Available
# 24   50.91986372661355  Not Avaliable      Not Available     Not Available
# 25           51.219924  Not Avaliable      Not Available     Not Available
# 26  50.896400787693985  Not Avaliable      Not Available     Not Available
# 27          51.1738111  Not Avaliable      Not Available     Not Available
# 28          50.4740113  Not Avaliable      Not Available     Not Available
# 29           50.719056  Not Avaliable      Not Available     Not Available
# 30          50.9272736  Not Avaliable      Not Available     Not Available
# 31          50.8563597  Not Avaliable      Not Available     Not Available
# 32          50.6086381  Not Avaliable      Not Available     Not Available
# 33          50.9879270  Not Avaliable      Not Available     Not Available
# 34           50.277127  Not Avaliable      Not Available     Not Available
# 35          51.2720860  Not Avaliable      Not Available     Not Available
# 36          50.5813094  Not Avaliable      Not Available     Not Available
# 37  50.507561581668426  Not Avaliable      Not Available     Not Available
# 38           50.709718  Not Avaliable      Not Available     Not Available
# 39          51.1267525  Not Avaliable      Not Available     Not Available
# 40          49.9941190  Not Avaliable      Not Available     Not Available
# 41          49.6400141  Not Avaliable      Not Available     Not Available
#
#    Contact Phone                     Contact Email
# 0   02/648.05.94                  info@nobel-sa.be
# 1   052/25.04.25             merchtem@handyhome.be
# 2   053/89.10.10          denderleeuw@handyhome.be
# 3   03/740.55.55                      info@fera.be
# 4   02 395 56 06                info@hobbylant.com
# 5   015/24.47.26  info@kerkstoel-bouwmaterialen.be
# 6   016/56.60.21                info@denankernv.be
# 7   065/67.45.93         info@doehetzelfcentrum.be
# 8   03/774.31.30             verkoop@dhzsaniver.be
# 9   068 26 88 50                    info@gondry.be
# 10  037/55.45.41       Gereedschappenluc@skynet.be
# 11  071/81.11.62                   info@falisse.be
# 12  013/77.11.11       bvba.vandendries@scarlet.be
# 13  011/58.62.01      quattro4bricostock@skynet.be
# 14  055/31.78.70                 info@ottevaere.be
# 15  081/25.03.30                   info@carlier.be
# 16  011/42.56.64                info@handystock.be
# 17  09/386.19.68          info@legerstockdeinze.be
# 18  085/84.12.00            rambeaux-dor@skynet.be
# 19  011/34.46.64                 klus@handyhome.be
# 20  019/32.22.11               corswarem@skynet.be
# 21  056/60.65.89                 info@europoint.be
# 22  051/68.83.93          info@devoldercoussens.be
# 23  011/34.26.45        administratie@luyckx-xl.be
# 24  056/66.65.49                 metalor@skynet.be
# 25  011/54.06.00              jana.moons@molsnv.be
# 26  051/30.33.57               info@globusbazar.be
# 27  050/79.06.30     tuinhobbystmarie@handyhome.be
# 28  085/51.30.88           brico.rulot@hotmail.com
# 29  04/358.30.03                   info@duvanco.be
# 30  089/71.32.05      info@schroedersdoehetzelf.be
# 31  056/50.92.04               dhzlouage@skynet.be
# 32  04/365.24.68                  gillon@skynet.be
# 33  089/77.52.56         bouwshopping@verheyen.com
# 34  084/46.70.74            compta@bricoservice.eu
# 35  059/23.36.10                  info@langelus.be
# 36  087/33.09.27                   info@conradt.be
# 37  087/54.16.26                   info@garsou.com
# 38  087/63.95.20               info@tychon-sprl.be
# 39  058/22.45.45                 info@vanmaele.com
# 40  061/21.75.40                   info@tecniba.be
# 41  063/24.26.15               contact@arma-sa.com

# %% [markdown]
# <h2>3. Plumart</h2>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd
import time


# Initialize the Selenium WebDriver
options = Options()
options.add_argument("--headless")  # Run in headless mode
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.plum-art.be/magasins-de-literie")
time.sleep(5)  # waktu tunggu agar JavaScript selesai render

# Simpan hasil HTML ke file
with open("plumart.html", "w", encoding="utf-8") as f:
    f.write(driver.page_source)
import json
import pandas as pd
import re

# Ekstrak bagian JS `var stores = [...]` dari HTML
with open("plumart.html", "r", encoding="utf-8") as f:
    html = f.read()

# Cari string stores = [...] dengan regex
match = re.search(r"var\s+stores\s*=\s*(\[\{.*?\}\]);", html, re.DOTALL)
stores_json = match.group(1) if match else None

# Convert JSON string jadi objek Python
if stores_json:
    # Decode karakter HTML (contoh: &#039;)
    from html import unescape
    decoded_json = unescape(stores_json)
    stores_data = json.loads(decoded_json)
else:
    stores_data = []

# Ambil informasi penting dari tiap store
parsed_data = []
for store in stores_data:
    address = store.get("address", {})
    parsed_data.append({
        "Location Name Name": store.get("name"),
        "Address": address.get("street"),
        "Latitude": store.get("latitude"),
        "Longitude": store.get("longitude"),
        "Postcode": address.get("postcode"),
        "City": address.get("city"),
        "Parking Type":"Not Avalilable",
        "Contact First Name":"Not Available",
        "Contact Last Name":"Not Available",
        "Contact Email":"Not Available",
        "Contact Phone": store.get("phone"),
    })

df = pd.DataFrame(parsed_data)
df.len

# %% [markdown]
# <h2>4. JYSK</h2>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd
import time


# Initialize the Selenium WebDriver
options = Options()
options.add_argument("--headless")  # Run in headless mode
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

driver.get("https://jysk.be/nl/winkels/genk/hasseltweg")
time.sleep(5)  # waktu tunggu agar JavaScript selesai render

# Simpan hasil HTML ke file
with open("jysk-store.html", "w", encoding="utf-8") as f:
    f.write(driver.page_source)
# Re-import everything after kernel reset
from bs4 import BeautifulSoup
import re

# Load the HTML file again
with open("jysk.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

# Locate the embedded JSON inside data-jysk-react-properties
store_locator_section = soup.find("section", id="stores-locator-ssr")
store_json = None

if store_locator_section:
    block = store_locator_section.find("div", attrs={"data-jysk-react-component": "StoresLocatorLayout"})
    if block and "data-jysk-react-properties" in block.attrs:
        raw_json = block["data-jysk-react-properties"]
        store_json = raw_json

store_json[:1000] if store_json else "Not found"
import json
import pandas as pd
from html import unescape

# Decode HTML entities
decoded_json = unescape(store_json)

# Parse JSON string
data = json.loads(decoded_json)

# Extract stores list
stores = data.get("storesCoordinates", [])

# Convert to structured DataFrame
store_data = []
for s in stores:
    full_address = f"{s.get('street', '')} {s.get('house', '')}, {s.get('zipcode', '')} {s.get('city', '')}"
    store_data.append({
        "Store Name": s.get("name"),
        "Full Address": full_address,
        "Latitude": s.get("lat"),
        "Longitude": s.get("lng"),
        "Outlet": s.get("outlet"),
        "URL Path": s.get("url"),
    })

df_jysk_final = pd.DataFrame(store_data)
df_jysk_final
# Out:
#                  Store Name  \
# 0                      Olen
# 1                   Lanaken
# 2                      Genk
# 3         Antwerpen-Schoten
# 4                  Tongeren
# ..                      ...
# 61  Saint Georges sur Meuse
# 62                     Lier
# 63                Drogenbos
# 64                    Diest
# 65                   Hannut
#
#                                          Full Address         Latitude  \
# 0              Lammersdries-winkelstraat 4, 2250 Olen  51.152395005733
# 1                           Steenweg 14, 3620 Lanaken       50.9139195
# 2                            Hasseltweg 38, 3600 Genk       50.9642976
# 3                      Bredabaan 1285 B, 2900 Schoten  51.267028722075
# 4                   Luikersteenweg 130, 3700 Tongeren       50.7696907
# ..                                                ...              ...
# 61  Rue Campagne du Moulin 49, 4470 Saint-Georges-...        50.604885
# 62                   Antwerpsesteenweg 364, 2500 Lier       51.1480804
# 63        Verlengde Stallestraat 215B, 1620 Drogenbos          50.7945
# 64                    Leuvensesteenweg 82, 3290 Diest       50.9745871
# 65                     Rue de Landen 53b, 4280 Hannut       50.6799886
#
#          Longitude  Outlet                                           URL Path
# 0   4.901697398672    True  /fr/stores-locator/olen/lammersdries-winkelstraat
# 1        5.6826993   False       /fr/stores-locator/lanaken/maaseikersteenweg
# 2        5.4733177    True                 /fr/stores-locator/genk/hasseltweg
# 3   4.463710784912   False               /fr/stores-locator/schoten/bredabaan
# 4        5.4649932   False         /fr/stores-locator/tongeren/luikersteenweg
# ..             ...     ...                                                ...
# 61        5.339157   False  /fr/stores-locator/saint-georges-sur-meuse/rue...
# 62       4.5377371   False          /fr/stores-locator/lier/antwerpsesteenweg
# 63         4.31201   False      /fr/magasins/drogenbos/verlengde-stallestraat
# 64       5.0392569   False                /fr/magasins/diest/leuvensesteenweg
# 65       5.0817914   False                  /fr/magasins/hannut/rue-de-landen
#
# [66 rows x 6 columns]

# %% [markdown]
# <h2>5. Extracting AH BE Stores</h2>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import pandas as pd
import time


# Initialize the Selenium WebDriver
options = Options()
options.add_argument("--headless")  # Run in headless mode
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.ah.be/winkels")
time.sleep(5)  # waktu tunggu agar JavaScript selesai render

# Simpan hasil HTML ke file
with open("ah-be.html", "w", encoding="utf-8") as f:
    f.write(driver.page_source)
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://www.ah.be/winkels"
}

def get_store_info(store_id):
    url = f"https://www.ah.be/winkel/{store_id}"
    res = requests.get(url, headers=headers)
    
    if res.status_code != 200:
        return None

    soup = BeautifulSoup(res.text, "html.parser")
    title_tag = soup.select_one('[data-testhook="store-title"]')
    address_tags = soup.select('[data-testhook="address-contact-details"] p')

    if not title_tag or len(address_tags) < 2:
        return None  # store not found or structure mismatch

    try:
        store_name = title_tag.get_text(strip=True)
        address = address_tags[0].get_text(strip=True)
        city_line = address_tags[1].get_text(strip=True)

        # Safe city split
        postal_code = ""
        city = city_line
        if " " in city_line:
            postal_code, city = city_line.split(" ", 1)

        phone_tag = soup.select_one('[data-testhook="store-phone"] p')
        phone = phone_tag.get_text(strip=True) if phone_tag else "Not available"

        services = [s.get_text(strip=True) for s in soup.select('[data-testhook="service"] h6')]

        return {
            "store_id": store_id,
            "store_name": store_name,
            "address": address,
            "postal_code": postal_code,
            "city": city,
            "phone": phone,
            "services": ", ".join(services),
            "url": url
        }
    except Exception as e:
        print(f"Error store {store_id}: {e}")
        return None

# Collect stores
store_list = []
for store_id in range(3000, 3201):
    print(f"Scraping store {store_id}...")
    data = get_store_info(store_id)
    if data:
        store_list.append(data)
    time.sleep(0.3)

# Save as DataFrame
df = pd.DataFrame(store_list)
import pandas as pd
import googlemaps
import time

# GANTI dengan API KEY kamu
API_KEY = 'AIzaSyCB_chRkK8VGHgBOr-rSS1t64PjKjbyQnM'
gmaps = googlemaps.Client(key=API_KEY)

df["Latitude"] = None
df["Longitude"] = None

# Loop dan geocode tiap alamat
for idx, row in df.iterrows():
    address = row["Full Address"]
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]["geometry"]["location"]
            df.at[idx, "Latitude"] = location["lat"]
            df.at[idx, "Longitude"] = location["lng"]
        else:
            df.at[idx, "Latitude"] = "Not found"
            df.at[idx, "Longitude"] = "Not found"
    except Exception as e:
        df.at[idx, "Latitude"] = "Error"
        df.at[idx, "Longitude"] = "Error"
    time.sleep(0.1)  # Untuk menghindari spike

# Simpan hasil ke Excel baru

# %% [markdown]
# <h2>6. Extracting Medimarket</h2>

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Load the saved HTML
with open("medi-market.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

# Extract store entries
stores = soup.select(".mobilo_storeSummary")
store_data = []

for store in stores:
    try:
        name = store.select_one("h2 a").get_text(strip=True)
        address_tags = store.select("address")[0].stripped_strings
        address_list = list(address_tags)
        address = address_list[0] if len(address_list) > 0 else "-"
        postal_city = address_list[1] if len(address_list) > 1 else "-"
        country = address_list[2] if len(address_list) > 2 else "-"
        phone_tag = store.select_one("a[href^='tel:']")
        phone = phone_tag.get_text(strip=True) if phone_tag else "-"

        full_address = f"{address}, {postal_city}, {country}"

        store_data.append({
            "Location Name": name,
            "Country": country,
            "Full Address": full_address,
            "Phone Number": phone
        })
    except Exception as e:
        print("Error extracting a store:", e)
        continue

df = pd.DataFrame(store_data)
df["Latitude"] = None
df["Longitude"] = None
API_KEY = 'AIzaSyCB_chRkK8VGHgBOr-rSS1t64PjKjbyQnM'
gmaps = googlemaps.Client(key=API_KEY)
# Loop dan geocode tiap alamat
for idx, row in df.iterrows():
    address = row["Full Address"]
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]["geometry"]["location"]
            df.at[idx, "Latitude"] = location["lat"]
            df.at[idx, "Longitude"] = location["lng"]
        else:
            df.at[idx, "Latitude"] = "Not found"
            df.at[idx, "Longitude"] = "Not found"
    except Exception as e:
        df.at[idx, "Latitude"] = "Error"
        df.at[idx, "Longitude"] = "Error"
    time.sleep(0.1)  # Untuk menghindari spike
df
# Out:
#                            Location Name     Country  \
# 0    Apotheek by Medi-Market Group Aalst     Belgium
# 1                      Medi-Market Aalst     Belgium
# 2          Medi-Market Westland Shopping     Belgium
# 3                 Medi-Market Anderlecht     Belgium
# 4      Institute by Medi-Market Westland     Belgium
# ..                                   ...         ...
# 111                   Medi-Market Massen  Luxembourg
# 112                 Medi-Market Wijnegem     Belgium
# 113             iU by Medi-Market Woluwé     Belgium
# 114  Apotheek by Medi-Market Group Zemst     Belgium
# 115                    Medi-Market Zemst     Belgium
#
#                                           Full Address  Phone Number  \
# 0      Gentsesteenweg, 442A bus 1, 9300 Aalst, Belgium  053 53 81 02
# 1            Gentsesteenweg, 442A, 9300 Aalst, Belgium  053 53 81 00
# 2    Boulevard Sylvain Dupuis, 309, 1070 Anderlecht...     024302504
# 3    Boulevard Industriel, 35, 1070 Anderlecht, Bel...  02 430 25 93
# 4    Boulevard Sylvain Dupuis, 309, 1070 Anderlecht...   02430 24 09
# ..                                                 ...           ...
# 111  Shopping-Center Massen - Wemperhardt, 24, 9999...   26 90 82 98
# 112  Wijnegem shopping 371 - 372 - Turnhoutsebaan, ...  03 600 70 90
# 113  Boulevard De La Woluwe, 70, 1200 Woluwe-Saint-...  02 430 25 06
# 114         Zemstsesteenweg, 219a, 1981 Zemst, Belgium  015 23 79 60
# 115          Zemstsesteenweg, 219, 1981 Zemst, Belgium  015 21 91 08
#
#       Latitude Longitude
# 0    50.941089  4.002626
# 1    50.941218  4.002586
# 2    50.838492  4.288036
# 3    50.825181  4.309848
# 4    50.838492  4.288036
# ..         ...       ...
# 111  50.148628    6.0574
# 112  51.226931  4.517735
# 113  50.844621  4.437103
# 114  50.991543   4.47324
# 115  50.991543   4.47324
#
# [116 rows x 6 columns]

# %% [markdown]
# <h2>7. Jumbo Store</h2>

# %%
import json
import pandas as pd

# Load the JSON file
with open("jumbo-netherland.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Traverse to the grid content holding store data
store_data = []

def extract_store_info(children):
    for child in children:
        if isinstance(child, dict):
            if child.get("type") == "fep-grid-cell":
                store_info = {}
                name, address, url = None, None, None

                for subchild in child.get("children", []):
                    if subchild["type"] == "fep-heading":
                        name = subchild["properties"].get("markdownText", "").replace("**", "").strip()
                    elif subchild["type"] == "fep-rich-text":
                        address = subchild["properties"].get("content", "").replace("<br>", ", ").replace("\r\n", "").replace("&nbsp;", " ").strip()
                    elif subchild["type"] == "fep-button":
                        url = "https://www.jumbo.com" + subchild["properties"].get("href", "")

                if name and address and url:
                    store_data.append({
                        "Store Name": name,
                        "Address": address,
                        "URL": url
                    })

            if "children" in child:
                extract_store_info(child["children"])

# Start recursive extraction
for block in data.get("data", []):
    if block.get("type") == "fep-container":
        extract_store_info(block.get("children", []))

# Convert to DataFrame
df_jumbo_be = pd.DataFrame(store_data)
df_jumbo_be["Latitude"] = None
df_jumbo_be["Longitude"] = None
API_KEY = 'AIzaSyCB_chRkK8VGHgBOr-rSS1t64PjKjbyQnM'
gmaps = googlemaps.Client(key=API_KEY)
# Loop dan geocode tiap alamat
for idx, row in df_jumbo_be.iterrows():
    address = row["Full Address"]
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]["geometry"]["location"]
            df_jumbo_be.at[idx, "Latitude"] = location["lat"]
            df_jumbo_be.at[idx, "Longitude"] = location["lng"]
        else:
            df_jumbo_be.at[idx, "Latitude"] = "Not found"
            df_jumbo_be.at[idx, "Longitude"] = "Not found"
    except Exception as e:
        df_jumbo_be.at[idx, "Latitude"] = "Error"
        df_jumbo_be.at[idx, "Longitude"] = "Error"
    time.sleep(0.1)  # Untuk menghindari spike
df_jumbo_be

# %%
# Load Excel
df = pd.read_csv('Delhaize - external sheet - Sheet1.csv')

# %%
df
# Out:
#      Catégorie                               name  Column 1 status  \
# 0     Delhaize                 Delhaize Fort Jaco       NaN   OPEN
# 1     Delhaize                   Delhaize Theodor       NaN   OPEN
# 2     Delhaize                      Delhaize Reet       NaN   OPEN
# 3     Delhaize                  Delhaize Boondael       NaN   OPEN
# 4     Delhaize                  Delhaize Veeweyde       NaN   OPEN
# ..         ...                                ...       ...    ...
# 373  Shop & Go  Shop & Go Delhaize Trompe Kemzeke       NaN   OPEN
# 374  Shop & Go         Shop & Go Delhaize UZ Gent       NaN   OPEN
# 375  Shop & Go      Shop & Go Delhaize Villerslei       NaN   OPEN
# 376  Shop & Go     Shop & Go Delhaize Zwijndrecht       NaN   OPEN
# 377  Shop & Go                      SHOP KOBBEGEM       NaN   OPEN
#
#            brand  externalId         phone               email  \
# 0    supermarket    10014006  3.223721e+09  014006@delhaize.be
# 1    supermarket    10014019  3.224269e+09  014019@delhaize.be
# 2    supermarket    10014022  3.238882e+09  014022@delhaize.be
# 3    supermarket    10014024  3.226729e+09  014024@delhaize.be
# 4    supermarket    10014044  3.225238e+09  014044@delhaize.be
# ..           ...         ...           ...                 ...
# 373    shopandgo    10047438  3.237797e+09  047438@delhaize.be
# 374    shopandgo    10047484  3.249931e+09  047484@delhaize.be
# 375    shopandgo    10047347  3.236853e+09  047347@delhaize.be
# 376    shopandgo    10047542  3.232530e+09  047542@delhaize.be
# 377  supermarket    10014399           NaN  014399@delhaize.be
#
#          synthetic_email                                                url  \
# 0                    NaN   https://stores.delhaize.be/fr/delhaize-fort-jaco
# 1    0014019@delhaize.be     https://stores.delhaize.be/fr/delhaize-theodor
# 2                    NaN        https://stores.delhaize.be/nl/delhaize-reet
# 3    0014024@delhaize.be    https://stores.delhaize.be/fr/delhaize-boondael
# 4    0014044@delhaize.be    https://stores.delhaize.be/fr/delhaize-veeweyde
# ..                   ...                                                ...
# 373                  NaN  https://stores.delhaize.be/nl/shop-and-go-delh...
# 374                  NaN  https://stores.delhaize.be/nl/shop-and-go-delh...
# 375                  NaN  https://stores.delhaize.be/nl/shop-and-go-delh...
# 376                  NaN  https://stores.delhaize.be/nl/shop-and-go-delh...
# 377                  NaN        https://stores.delhaize.be/nl/shop-kobbegem
#
#      Googlemaps link  Coordinates  Latitude Longitude
# 0                NaN           NaN     None      None
# 1                NaN           NaN     None      None
# 2                NaN           NaN     None      None
# 3                NaN           NaN     None      None
# 4                NaN           NaN     None      None
# ..               ...           ...      ...       ...
# 373              NaN           NaN     None      None
# 374              NaN           NaN     None      None
# 375              NaN           NaN     None      None
# 376              NaN           NaN     None      None
# 377              NaN           NaN     None      None
#
# [378 rows x 14 columns]

# %%
# Loop dan geocode tiap alamat
for idx, row in df.iterrows():
    address = row["name"]
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]["geometry"]["location"]
            df.at[idx, "Latitude"] = location["lat"]
            df.at[idx, "Longitude"] = location["lng"]
        else:
            df.at[idx, "Latitude"] = "Not found"
            df.at[idx, "Longitude"] = "Not found"
    except Exception as e:
        df.at[idx, "Latitude"] = "Error"
        df.at[idx, "Longitude"] = "Error"
    time.sleep(0.1)  # Untuk menghindari spike

# Simpan hasil ke Excel baru
